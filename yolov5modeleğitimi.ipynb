# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17608, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 17608 (delta 7), reused 2 (delta 2), pack-reused 17593 (from 2)
# Receiving objects: 100% (17608/17608), 16.82 MiB | 10.38 MiB/s, done.
# Resolving deltas: 100% (11983/11983), done.
# /content/drive/MyDrive/disordo/disordo/yolov5
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/drive/MyDrive/disordo/disordo/data.yaml --weights yolov5s.pt --project runs_disordo --name yolov5s_v1
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt

# !python train.py --img 320 --batch 4 --epochs 5 \
  --data /content/drive/MyDrive/disordo/disordo/data.yaml \
  --weights yolov5n.pt --device cpu \
  --project runs_disordo --name yolov5n_cpu_test
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17608, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 17608 (delta 7), reused 2 (delta 2), pack-reused 17593 (from 2)
# Receiving objects: 100% (17608/17608), 16.84 MiB | 32.23 MiB/s, done.
# Resolving deltas: 100% (11991/11991), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.3 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# ...
